# %% [markdown]
# <a href="https://colab.research.google.com/github/Talhaa07/Autocarslist_scraping/blob/main/autocarslist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Importing Libraries
import requests
import pandas as pd
import json

# %%
headers = {
    'authority': 'www.autolist.com',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'no-cache',
    'cookie': '_gcl_au=1.1.279467782.1704991364; _pubcid=120d4613-123d-4268-82cc-608c621d571d; _pubcid_cst=zix7LPQsHA^%^3D^%^3D; _fbp=fb.1.1704991448843.1635638377; ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzEyMC4wLjAuMCBTYWZhcmkvNTM3LjM2In0=; client_guid_timestamp=cd801a35-518c-46ae-9d56-fb34c9dfb202.1704991343076; _gid=GA1.2.2049371842.1705138333; _sp_ses.8ca5=*; _uetsid=a293d420b1f611ee989cdb3090834dc1; _uetvid=715333c0b0a011eea44d175fa12112a1; _ga=GA1.1.861218591.1704991451; __gads=ID=58b8c4f8af84b5bd:T=1705138338:RT=1705138338:S=ALNI_MaDkXbsOid1GRevYWRlGaPwaA_SCw; __gpi=UID=00000cf4d919312a:T=1705138338:RT=1705138338:S=ALNI_Ma0V6wApa9Xz8_Xq6JZiN6hT2D2Bw; panoramaId_expiry=1705743145850; _cc_id=64bca8010fb8ae2eb7b18c3fa3c66690; panoramaId=00285ad43596fb30ba2efb0f12d616d5393896ba6b89cb82d3302c592ed8bb1b; pbjs-unifiedid=^%^7B^%^22TDID^%^22^%^3A^%^22b738f430-2931-47a2-aee0-b98974673a2f^%^22^%^2C^%^22TDID_LOOKUP^%^22^%^3A^%^22TRUE^%^22^%^2C^%^22TDID_CREATED_AT^%^22^%^3A^%^222023-12-13T09^%^3A32^%^3A25^%^22^%^7D; pbjs-unifiedid_cst=zix7LPQsHA^%^3D^%^3D; cto_bundle=; cto_bidid=94c2v19YRlQ5TEtrblNxckF1b1RZWFJKS291WWptMzhEaExDQWU3RVNLOUw4aUJQTFB4MUFFeiUyRmd0cXFVekpxdDlYaTJEV0JHJTJCV0taVnpZRSUyQk5wOTclMkJja3pwWEhQWEZLY0dRWjFjQnFVekxPdlV3JTNE; _ga_KKZ1EQJKEV=GS1.1.1705138335.2.1.1705138377.0.0.0; _sp_id.8ca5=2d07cb04-9dc8-4472-9aad-53e3fbdc57e4.1704991377.2.1705138444.1704991676.3a861db1-012f-4fa9-b581-8d97f633eb1b',
    'pragma': 'no-cache',
    'referer': 'https://www.autolist.com/tesla-model+3',
    'sec-ch-ua': '^\\^Not_A',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
}

params = (
    ('ads', 'true'),
    ('include_total_price_change', 'true'),
    ('include_time_on_market', 'true'),
    ('include_relative_price_difference', 'true'),
    ('latitude', '33.7233'),
    ('limit', '20'),
    ('locale', 'en'),
    ('longitude', '73.0435'),
    ('make', 'Tesla'),
    ('model', 'Model^%^203'),
    ('page', '1'),
    ('radius', '100'),
    ('sort_new_cars_last', 'true'),
)

response = requests.get('https://www.autolist.com/api/v2/search', headers=headers, params=params)
res = response.json()

# %%
##checking responce keys
res.keys()
# Out:
# dict_keys(['total_count', 'total_count_formatted', 'hits_count', 'records', 'promoted_aggregations', 'facet_counts', 'ad_info'])

# %%
##Scraping data for the first one to check whether our code is working or not
cars = res['records']

# %%
cars[0]
# Out:
# {'id': 280045221,
#  'accepts_click_off': True,
#  'accepts_leads': True,
#  'accepts_leads_and_click_off': True,
#  'always_ask_for_zip': True,
#  'available_nationwide': False,
#  'backup_camera': False,
#  'bed': None,
#  'bluetooth': True,
#  'body_style': 'sedan',
#  'body_type': 'sedan',
#  'cabin': None,
#  'categories': ['american'],
#  'city': 'Woodbridge',
#  'city_mpg': None,
#  'clickoff_url': 'https://www.carmax.com/car/24656589?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#  'combined_mpg': None,
#  'condition': 'used',
#  'cpl_value': 15,
#  'created_at': '2023-12-08T15:14:01.511Z',
#  'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520',
#  'dealer_name': 'CarMax Potomac Mills - Now offering Curbside Pickup and Home Delivery',
#  'distance_from_origin': 7085,
#  'door_count': 4,
#  'driveline': 'AWD',
#  'eligible_for_financing': False,
#  'email_opt_default': True,
#  'engine_cylinders': None,
# ...

# %%
##Model name
cars[0]['model_name']
# Out:
# 'Model 3'

# %%
##Milage
cars[0]['mileage']
# Out:
# 56050

# %%
##Model_id
cars[0]['model_id']
# Out:
# 2217

# %%
##phone
cars[0]['phone']
# Out:
# '(703) 576-6552'

# %%
##price
cars[0]['price']
# Out:
# 31998

# %%
##dealarname
dealar = cars[0]['dealer_name'].split("-")

# %%
dealar[0]
# Out:
# 'CarMax Potomac Mills '

# %%
##city
cars[0]['city']
# Out:
# 'Woodbridge'

# %%
Model = []
price = []
city = []
milage = []
model_id = []
delar_name = []
phone = []
for car in cars:
  ##Model
  Model.append(car['model_name'])
  ##Price
  price.append(car['price'])
  ##Price
  city.append(car['city'])
  ##Mileage
  milage.append(car['mileage'])
  ##Model_id
  model_id.append(car['model_id'])
  ##Dealar_name
  dealar = car['dealer_name'].split("-")
  delar_name.append(dealar[0])
  ##Phone
  phone.append(car['phone'])

# %%
df = pd.DataFrame({'Model':Model,"Price $":price,"City":city,"Mileage":milage,"Model_id":model_id,"dealar":delar_name,"Phone":phone})

# %%
df
# Out:
#       Model  Price $          City  Mileage  Model_id  \
# 0   Model 3    31998    Woodbridge    56050      2217
# 1   Model 3    35998        Irvine    19167      2217
# 2   Model 3    44998      Murrieta    18300      2217
# 3   Model 3    29998        Irvine    53086      2217
# 4   Model 3    29998    Buena Park    51661      2217
# 5   Model X    61998         Colma    22230      2101
# 6   Model 3    33998    Buena Park    18563      2217
# 7   Model 3    35998    Fort Worth     8675      2217
# 8   Model 3    41998         Pharr    16850      2217
# 9   Model Y    45998       Gilbert    17965      2357
# 10  Model 3    28998   Canoga Park    57235      2217
# 11  Model 3    31998         Tampa    24939      2217
# 12  Model 3    30998      Murrieta    34203      2217
# 13  Model 3    38998    Woodbridge    10388      2217
# 14  Model Y    44998    Fort Worth    27727      2357
# 15  Model 3    32998     Inglewood    45625      2217
# ...

# %%
##Now scraping 5 pages data
## Will use loop here

headers = {
    'authority': 'www.autolist.com',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'no-cache',
    'cookie': '_gcl_au=1.1.279467782.1704991364; _pubcid=120d4613-123d-4268-82cc-608c621d571d; _pubcid_cst=zix7LPQsHA^%^3D^%^3D; _fbp=fb.1.1704991448843.1635638377; ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzEyMC4wLjAuMCBTYWZhcmkvNTM3LjM2In0=; client_guid_timestamp=cd801a35-518c-46ae-9d56-fb34c9dfb202.1704991343076; _gid=GA1.2.2049371842.1705138333; _sp_ses.8ca5=*; _uetsid=a293d420b1f611ee989cdb3090834dc1; _uetvid=715333c0b0a011eea44d175fa12112a1; _ga=GA1.1.861218591.1704991451; __gads=ID=58b8c4f8af84b5bd:T=1705138338:RT=1705138338:S=ALNI_MaDkXbsOid1GRevYWRlGaPwaA_SCw; __gpi=UID=00000cf4d919312a:T=1705138338:RT=1705138338:S=ALNI_Ma0V6wApa9Xz8_Xq6JZiN6hT2D2Bw; panoramaId_expiry=1705743145850; _cc_id=64bca8010fb8ae2eb7b18c3fa3c66690; panoramaId=00285ad43596fb30ba2efb0f12d616d5393896ba6b89cb82d3302c592ed8bb1b; pbjs-unifiedid=^%^7B^%^22TDID^%^22^%^3A^%^22b738f430-2931-47a2-aee0-b98974673a2f^%^22^%^2C^%^22TDID_LOOKUP^%^22^%^3A^%^22TRUE^%^22^%^2C^%^22TDID_CREATED_AT^%^22^%^3A^%^222023-12-13T09^%^3A32^%^3A25^%^22^%^7D; pbjs-unifiedid_cst=zix7LPQsHA^%^3D^%^3D; cto_bundle=; cto_bidid=94c2v19YRlQ5TEtrblNxckF1b1RZWFJKS291WWptMzhEaExDQWU3RVNLOUw4aUJQTFB4MUFFeiUyRmd0cXFVekpxdDlYaTJEV0JHJTJCV0taVnpZRSUyQk5wOTclMkJja3pwWEhQWEZLY0dRWjFjQnFVekxPdlV3JTNE; _ga_KKZ1EQJKEV=GS1.1.1705138335.2.1.1705138377.0.0.0; _sp_id.8ca5=2d07cb04-9dc8-4472-9aad-53e3fbdc57e4.1704991377.2.1705138444.1704991676.3a861db1-012f-4fa9-b581-8d97f633eb1b',
    'pragma': 'no-cache',
    'referer': 'https://www.autolist.com/tesla-model+3',
    'sec-ch-ua': '^\\^Not_A',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',

}
Model = []
price = []
city = []
milage = []
model_id = []
delar_name = []
phone = []
for i in range(1,6):
  params = (
      ('ads', 'true'),
      ('include_total_price_change', 'true'),
      ('include_time_on_market', 'true'),
      ('include_relative_price_difference', 'true'),
      ('latitude', '33.7233'),
      ('limit', '20'),
      ('locale', 'en'),
      ('longitude', '73.0435'),
      ('make', 'Tesla'),
      ('model', 'Model^%^203'),
      ('page', str(i)),
      ('radius', '100'),
      ('sort_new_cars_last', 'true'),
  )
  ##Response varaiable for getting requests
  response = requests.get('https://www.autolist.com/api/v2/search', headers=headers, params=params)
  ##Getting json object
  res = response.json()
  result = res['records']
  for car in cars:
    ##Model
    try:
      Model.append(car['model_name'])
    except:
      None
    ##Price
    price.append(car['price'])
    ##Price
    city.append(car['city'])
    ##Mileage
    milage.append(car['mileage'])
    ##Model_id
    model_id.append(car['model_id'])
    ##Dealar_name
    dealar = car['dealer_name'].split("-")
    delar_name.append(dealar[0])
    ##Phone
    phone.append(car['phone'])
    df = pd.DataFrame({'Model':Model,"Price $":price,"City":city,"Mileage":milage,"Model_id":model_id,"dealar":delar_name,"Phone":phone})

# %%
df
# Out:
#       Model  Price $          City  Mileage  Model_id  \
# 0   Model 3    31998    Woodbridge    56050      2217
# 1   Model 3    35998        Irvine    19167      2217
# 2   Model 3    44998      Murrieta    18300      2217
# 3   Model 3    29998        Irvine    53086      2217
# 4   Model 3    29998    Buena Park    51661      2217
# ..      ...      ...           ...      ...       ...
# 95  Model 3    32998     Inglewood    45625      2217
# 96  Model Y    48998        Golden     3639      2357
# 97  Model 3    29998        Laurel    62575      2217
# 98  Model 3    30998  Jacksonville    23756      2217
# 99  Model 3    31998  Gaithersburg    46019      2217
#
#                        dealar           Phone
# 0       CarMax Potomac Mills   (703) 576-6552
# 1              CarMax Irvine   (949) 450-6148
# 2            CarMax Murrieta   (951) 387-3862
# 3              CarMax Irvine   (949) 450-6148
# 4          CarMax Buena Park   (714) 736-4207
# ...

# %%
df.to_csv("Cars_data.csv")
